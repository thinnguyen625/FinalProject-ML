# %% [markdown]
# <center>
#     <h1><b>NHẬP MÔN HỌC MÁY - CQ2017</b></h1>
#     <h2>ĐỒ ÁN CUỐI KỲ</h2>
#     <h2>Nhận diện chữ viết tay với SVM</h2>
#     <h3>Giảng viên hướng dẫn: Trần Trung Kiên</h3>
#     <h3>Trợ giảng: Phạm Trọng Nghĩa - Phan Thị Phương Uyên</h3>
#     <hr width='20%'>
#     <h3>Nhóm sinh viên:</h3>
#     <div style="display: inline-block; text-align: left;">
#         1712787 - Nguyễn Văn Thìn<br>
#         1712920 - Nguyễn Minh Vũ<br>
#         1712921 - Nguyễn Thái Vũ<br>
#     </div>
#     <hr width='20%'>
#     <h1><b>RBF Kernel</b></h1>
#     <h2>Huấn luyện - Dự đoán - Ghi nhận kết quả</h2>
# </center>

# %% [markdown]
# ### Cần phải đặt notebook này cùng thư mục với dữ liệu `mnist.pkl.gz` và mà nguồn [`svm_rbf.py`]('rbf/svm_rbf.py')
#
# ### Nếu sử dụng notebook này trên Google Colab, chạy cell này
#
# [Thư mục Drive chứa các notebook đã chạy sẵn](https://drive.google.com/drive/folders/1qE9OCkhkEGVyd1d4cXbUimHVX9W7WRsG?usp=sharing)
#
# (Các thầy cô gửi request em sẽ add vào làm editor. Bây giờ em chưa mở public được ạ)

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
my_drive = GoogleDrive(gauth)
from google.colab import drive
drive.mount('/content/drive')

def permanently_del(file_name):
    '''
    This function used to delete the file which has file_name in your Drive's trash bin (to prevent the lack of space during running)
    '''
    query = {'q': 'title=\'' + file_name + '\'' + ' and trashed=true' }
    for f in my_drive.ListFile(query).GetList():
         f.Delete()
# %cd /content/drive/My Drive/ML-CQ2017-Final/FinalProject

# %% [markdown]
# ### `import` mã nguồn
#
# và khai báo một số biến cần dùng:
#
# - `n_samples`: điều chỉnh số mẫu để chạy (phải nhỏ hơn kích thước của `val_Y` và `test_Y`)
#
# - `gammas`: nếu không muốn dùng các $\gamma$ (gamma) mặc định (`[0.0005, 0.005, 0.025, 0.05, 0.25, 0.5]`)
#
# - `strategy`: nếu không muốn dùng chiến lược phân loại mặc định `ovo`

# %%
from svm_rbf import multi_rbf
n_samples = 50000
gammas = [0.0005, 0.005, 0.025, 0.05, 0.25, 0.5]
strategy = 'ovo'

# %% [markdown]
# ### Chạy kernel RBF với các tham số `C` và `gamma` khác nhau (chiến lược `ovo`)

# %%
#C=0.001
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=0.001
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=0.01
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=0.1
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=1.
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=5.
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=10.
m_rbf = multi_rbf(C=C, gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')

# %%
C=50.
m_rbf = multi_rbf(C=50., gammas=gammas, decision_function_shape=strategy).run(n_samples)
for s in m_rbf.single_rbf_list:
    permanently_del(s.name + '.pkl')
